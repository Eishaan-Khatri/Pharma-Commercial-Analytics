# %% [markdown]
# # 01 - EDA
#
# This notebook inspects the generated transaction sample and basic business metrics.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT))

from src.generate_sample_data import generate_transactions
from src.data_cleaning import clean_transactions

raw = generate_transactions(rows=25000)
clean, quality = clean_transactions(raw)
quality

# %%
clean.groupby('drug_category')['net_sales'].sum().sort_values(ascending=False).head(10)
