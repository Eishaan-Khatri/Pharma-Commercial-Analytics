# %% [markdown]
# # 04 - A/B-Style Analysis
#
# This notebook compares campaign and non-campaign groups. It is comparison analysis, not causal proof.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT))

from src.generate_sample_data import generate_transactions
from src.data_cleaning import clean_transactions
from src.ab_analysis import run_ab_style_analysis

raw = generate_transactions(rows=25000)
clean, _ = clean_transactions(raw)
summary, inference = run_ab_style_analysis(clean)
summary, inference
