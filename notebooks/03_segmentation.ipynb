# %% [markdown]
# # 03 - Segmentation
#
# This notebook clusters drug categories into commercial behavior segments.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT))

from src.generate_sample_data import generate_transactions
from src.data_cleaning import clean_transactions
from src.features import make_segmentation_features
from src.segmentation import run_segmentation

raw = generate_transactions(rows=25000)
clean, _ = clean_transactions(raw)
features = make_segmentation_features(clean)
scores, segmented, profiles = run_segmentation(features)
profiles
