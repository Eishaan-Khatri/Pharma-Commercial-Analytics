# %% [markdown]
# # 02 - Forecasting
#
# This notebook builds month-category features and compares simple forecasting baselines.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT))

from src.generate_sample_data import generate_transactions
from src.data_cleaning import clean_transactions
from src.features import make_monthly_category_features
from src.forecasting import run_forecasting

raw = generate_transactions(rows=25000)
clean, _ = clean_transactions(raw)
monthly = make_monthly_category_features(clean)
metrics, predictions = run_forecasting(monthly)
metrics
